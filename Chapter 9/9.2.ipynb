% %% [markdown]
% # 9.2

% %% [markdown]
% ## 9.2.1

% %%
A = imread('broken_text.tif');
B = [0 1 0; 1 1 1; 0 1 0];
D = imdilate(A, B);
imshow(A)
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)

% %%
imshow(D)
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)

% %% [markdown]
% ## 9.2.3

% %%
se = strel('diamond', 5)
% Out:
% se =
%
% strel is a diamond shaped structuring element with properties:
%
%       Neighborhood: [11x11 logical]
%     Dimensionality: 2

% %%
decomp = getsequence(se);
whos
% Out:
%   Name          Size               Bytes  Class      Attributes
%
%   A           889x1019            905891  logical
%   B             3x3                   72  double
%   D           889x1019            905891  logical
%   decomp        4x1                  576  strel
%   se            1x1                 2264  strel

% %%
decomp(1)
% Out:
% ans =
%
% strel is a arbitrary shaped structuring element with properties:
%
%       Neighborhood: [3x3 logical]
%     Dimensionality: 2

% %%
decomp(2)
% Out:
% ans =
%
% strel is a arbitrary shaped structuring element with properties:
%
%       Neighborhood: [3x3 logical]
%     Dimensionality: 2

% %%
decomp(3)
% Out:
% ans =
%
% strel is a arbitrary shaped structuring element with properties:
%
%       Neighborhood: [5x5 logical]
%     Dimensionality: 2

% %%
decomp(4)
% Out:
% ans =
%
% strel is a arbitrary shaped structuring element with properties:
%
%       Neighborhood: [3x3 logical]
%     Dimensionality: 2

% %% [markdown]
% ## 9.2.4

% %%
A = imread('wirebond_mask.tif');
imshow(A)
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)

% %%
se = strel('disk', 10);
E10 = imerode(A, se);
imshow(E10)
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)

% %%
se = strel('disk', 5);
E5 = imerode(A, se);
imshow(E5)
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)

% %%
E20 = imerode(A, strel('disk', 20));
imshow(E20)
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)
