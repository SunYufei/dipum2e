% %% [markdown]
% # 6.4

% %% [markdown]
% ## Example 6.5

% %%
f = imread('Fig0615.tif');
g = ice('image', f);
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 50% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)
%   In ice
%   In ice
%   In gui_mainfcn (line 220)
%   In ice

% %%
g = ice('image', f, 'wait', 'off');

% %%
g = ice('image', f, 'space', 'hsi');

% %%
f = imread('Fig0617(a).tif');
g = ice('image', f);
% Out:
% 警告: 图像太大，无法在屏幕上显示；将以 67% 显示
% > In images.internal.initSize (line 71)
%   In imshow (line 336)
%   In ice
%   In ice
%   In gui_mainfcn (line 220)
%   In ice

% %% [markdown]
% ## Example 6.6

% %%
f = imread('Fig0618(a).tif');
g1 = ice('image', f);

% %% [markdown]
% ## Example 6.7

% %% [markdown]
% ## Example 6.8

% %% [markdown]
% ## Example 6.9
