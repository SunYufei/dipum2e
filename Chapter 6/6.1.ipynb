% %% [markdown]
% # 6.1

% %%
rgbcube(200, 200, 200);

% %%
f = imread('Fig0604(a).tif');
imshow(f)

% %%
[X1, map1] = rgb2ind(f, 8, 'nodither');
imshow(X1, map1)

% %%
[X2, map2] = rgb2ind(f, 8, 'dither');
imshow(X2, map2)

% %%
g = rgb2gray(f);
g1 = dither(g);
imshow(g);

% %%
imshow(g1);
